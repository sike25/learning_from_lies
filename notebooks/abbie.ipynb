# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torchvision import datasets, transforms
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
import numpy as np
import time
import math

# %% [markdown]
# ### Set - Up

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Parameters
noise_dim = 10
image_dim = 28
batch_size = 64

max_translate = 6
max_rotation = 20

# %%
# Load MNIST and extract one sample per class
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transforms.ToTensor())
test_dataset = datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor())

base_images, base_labels = [], []
seen_classes = set()
for img, label in train_dataset:
    if label not in seen_classes:
        base_images.append(img)
        base_labels.append(label)
        seen_classes.add(label)
    if len(seen_classes) == 10:
        break
base_images = torch.stack(base_images, dim=0).to(device)
base_labels = torch.tensor(base_labels, dtype=torch.long).to(device)

# %%
# Define Classifier CNN
class ClassifierCNN(nn.Module):
    def __init__(self, num_outputs):
        super().__init__()
        self.feature_extractor = nn.Sequential(
            nn.Conv2d(1, 8, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(8, 16, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Flatten(),
            nn.Linear(16 * 7 * 7, 64),
            nn.ReLU(),
        )
        self.head = nn.Linear(64, num_outputs)

    def forward(self, x):
        features = self.feature_extractor(x)
        return self.head(features)

# %% [markdown]
# ### Utilities

# %%
# Evaluation function
def evaluate(model):
    test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1000, shuffle=False)
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    model.train()
    return correct / total

# %% [markdown]
# ### Experiment

# %%
def run(startup_proportion, total_training_steps, eval_interval):
    # Initialize models and optimizers
    classifier = ClassifierCNN(num_outputs=1).to(device)
    optimizer_c = torch.optim.Adam(classifier.parameters(), lr=3e-4)

    # Fake data generator (simple random noise)
    def generate_fake_batch(batch_size):
        imgs = torch.rand(batch_size, 1, 28, 28, device=device)
        imgs = (imgs > 0.5).float()
        labels = imgs.sum(dim=[1,2,3])
        return imgs, labels

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    steps_per_epoch = len(train_loader)

    # Calculate how much training is online vs disk
    online_steps = int(startup_proportion * total_training_steps)
    disk_steps = total_training_steps - online_steps
    disk_epochs = math.ceil(disk_steps / steps_per_epoch)

    scheduler_c = torch.optim.lr_scheduler.OneCycleLR(
        optimizer_c, max_lr=3e-4, total_steps=total_training_steps
    )

    criterion = nn.MSELoss()

    start = time.time()

    # Online training
    print('Synthetic Training...')
    loss_history = []
    accuracy_history = []
    for step in range(1, online_steps + 1):
        fake_images, fake_labels = generate_fake_batch(batch_size)

        optimizer_c.zero_grad()
        preds = classifier(fake_images)
        loss = criterion(preds.squeeze(), fake_labels)
        loss.backward()
        scheduler_c.step()
        optimizer_c.step()

        if step % eval_interval == 0:
            loss_history.append(loss.item())
            print(f'Loss: {loss.item():.4f}')

    # Replace classifier head for real MNIST classification
    classifier.head = nn.Linear(64, 10).to(device)
    optimizer_c = torch.optim.Adam(classifier.parameters(), lr=3e-4)
    criterion = nn.CrossEntropyLoss()

    # Disk training
    print('Natural Training...')
    step = 0
    for epoch in range(1, disk_epochs + 1):
        for real_images, real_labels in train_loader:
            if step >= disk_steps:
                break
            real_images, real_labels = real_images.to(device), real_labels.to(device)

            optimizer_c.zero_grad()
            logits = classifier(real_images)
            loss = criterion(logits, real_labels)
            loss.backward()
            scheduler_c.step()
            optimizer_c.step()

            step += 1

            if step % eval_interval == 0:
                acc = evaluate(classifier)
                accuracy_history.append(acc)
                print(f'Loss: {loss.item():.4f} | Accuracy: {acc:.4f}')

    end = time.time()

    elapsed_time = end - start
    return elapsed_time, accuracy_history, loss_history

# %%
# Main Experiment Loop
total_steps  = 200
eval_interval = 5
percentages   = [round(0.1 * p, 2) for p in range(10)]

times        = {}
losses       = {}
accuracies   = {}

for percent in percentages:
    print(f"\nTesting {percent*100}% online...")
    t, a, l = run(percent, total_steps, eval_interval)

    times[percent] = t
    losses[percent] = l
    accuracies[percent] = a
# Out:
# Testing 0.0% online...
# Synthetic Training...
# Natural Training...
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:227: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# Loss: 2.2734 | Accuracy: 0.1135
# Loss: 2.3119 | Accuracy: 0.1135
# Loss: 2.2860 | Accuracy: 0.1135
# Loss: 2.2681 | Accuracy: 0.1135
# Loss: 2.2748 | Accuracy: 0.1135
# Loss: 2.2638 | Accuracy: 0.1533
# Loss: 2.2519 | Accuracy: 0.3101
# Loss: 2.2271 | Accuracy: 0.4094
# Loss: 2.1983 | Accuracy: 0.4397
# Loss: 2.2122 | Accuracy: 0.5063
# Loss: 2.2013 | Accuracy: 0.5421
# Loss: 2.1310 | Accuracy: 0.5385
# Loss: 2.1455 | Accuracy: 0.6238
# Loss: 2.0914 | Accuracy: 0.7376
# Loss: 2.0597 | Accuracy: 0.6963
# Loss: 2.0219 | Accuracy: 0.6392
# Loss: 1.9423 | Accuracy: 0.6347
# Loss: 1.9622 | Accuracy: 0.6315
# Loss: 1.8954 | Accuracy: 0.6673
# Loss: 1.7691 | Accuracy: 0.7358
# Loss: 1.7522 | Accuracy: 0.7138
# Loss: 1.7346 | Accuracy: 0.7091
# Loss: 1.6787 | Accuracy: 0.6763
# Loss: 1.6258 | Accuracy: 0.7405
# Loss: 1.4377 | Accuracy: 0.7788
# Loss: 1.4224 | Accuracy: 0.7470
# Loss: 1.3963 | Accuracy: 0.7309
# Loss: 1.2420 | Accuracy: 0.7716
# Loss: 1.1330 | Accuracy: 0.7905
# Loss: 1.0911 | Accuracy: 0.8013
# Loss: 1.0664 | Accuracy: 0.7857
# Loss: 0.9716 | Accuracy: 0.7728
# Loss: 0.9247 | Accuracy: 0.7888
# Loss: 0.9227 | Accuracy: 0.8154
# Loss: 0.8836 | Accuracy: 0.7765
# Loss: 0.7129 | Accuracy: 0.8086
# Loss: 0.7361 | Accuracy: 0.8219
# Loss: 0.7605 | Accuracy: 0.8283
# Loss: 0.7291 | Accuracy: 0.8233
# Loss: 0.7284 | Accuracy: 0.8234
#
# Testing 10.0% online...
# Synthetic Training...
# Loss: 154317.8906
# Loss: 153018.3750
# Loss: 152511.0469
# Loss: 151272.3594
# Natural Training...
# Loss: 2.3029 | Accuracy: 0.1028
# Loss: 2.2931 | Accuracy: 0.1636
# Loss: 2.2758 | Accuracy: 0.2938
# Loss: 2.2477 | Accuracy: 0.3876
# Loss: 2.2368 | Accuracy: 0.3917
# Loss: 2.2409 | Accuracy: 0.4294
# Loss: 2.1959 | Accuracy: 0.4415
# Loss: 2.1999 | Accuracy: 0.4510
# Loss: 2.1670 | Accuracy: 0.5751
# Loss: 2.1329 | Accuracy: 0.5980
# Loss: 2.0453 | Accuracy: 0.5387
# Loss: 1.9947 | Accuracy: 0.5715
# Loss: 1.9700 | Accuracy: 0.5368
# Loss: 1.9417 | Accuracy: 0.6291
# Loss: 1.8723 | Accuracy: 0.6584
# Loss: 1.7119 | Accuracy: 0.6337
# Loss: 1.7846 | Accuracy: 0.6423
# Loss: 1.6420 | Accuracy: 0.6388
# Loss: 1.7209 | Accuracy: 0.6827
# Loss: 1.4671 | Accuracy: 0.7087
# Loss: 1.4479 | Accuracy: 0.7007
# Loss: 1.3695 | Accuracy: 0.7407
# Loss: 1.3808 | Accuracy: 0.7533
# Loss: 1.1119 | Accuracy: 0.7634
# Loss: 1.2059 | Accuracy: 0.7458
# Loss: 1.0463 | Accuracy: 0.7838
# Loss: 1.0152 | Accuracy: 0.8039
# Loss: 0.9113 | Accuracy: 0.7739
# Loss: 0.8633 | Accuracy: 0.7869
# Loss: 1.0147 | Accuracy: 0.8071
# Loss: 0.7334 | Accuracy: 0.8134
# Loss: 0.7096 | Accuracy: 0.8149
# Loss: 0.8078 | Accuracy: 0.8092
# Loss: 0.6009 | Accuracy: 0.8137
# Loss: 0.6684 | Accuracy: 0.8334
# Loss: 0.7732 | Accuracy: 0.8388
#
# Testing 20.0% online...
# Synthetic Training...
# Loss: 154348.9688
# Loss: 152730.5781
# Loss: 154831.0781
# Loss: 154368.9062
# Loss: 152808.9062
# Loss: 153168.6094
# Loss: 155040.1094
# Loss: 152721.0469
# Natural Training...
# Loss: 2.2864 | Accuracy: 0.1180
# Loss: 2.3035 | Accuracy: 0.1889
# Loss: 2.2801 | Accuracy: 0.1790
# Loss: 2.2702 | Accuracy: 0.3826
# Loss: 2.2717 | Accuracy: 0.3887
# Loss: 2.1923 | Accuracy: 0.3962
# Loss: 2.1787 | Accuracy: 0.4719
# Loss: 2.1688 | Accuracy: 0.5259
# Loss: 2.1436 | Accuracy: 0.5789
# Loss: 2.0670 | Accuracy: 0.5991
# Loss: 1.9876 | Accuracy: 0.6090
# Loss: 1.9230 | Accuracy: 0.6168
# Loss: 1.9618 | Accuracy: 0.6004
# Loss: 1.6800 | Accuracy: 0.6015
# Loss: 1.7397 | Accuracy: 0.5727
# Loss: 1.7098 | Accuracy: 0.6215
# Loss: 1.5186 | Accuracy: 0.6458
# Loss: 1.4125 | Accuracy: 0.6734
# Loss: 1.3597 | Accuracy: 0.6918
# Loss: 1.3689 | Accuracy: 0.6916
# Loss: 1.2339 | Accuracy: 0.7034
# Loss: 1.1143 | Accuracy: 0.7058
# Loss: 1.0206 | Accuracy: 0.7373
# Loss: 1.0068 | Accuracy: 0.7453
# Loss: 0.8950 | Accuracy: 0.7353
# Loss: 1.0503 | Accuracy: 0.7608
# Loss: 0.8613 | Accuracy: 0.7723
# Loss: 0.8505 | Accuracy: 0.7882
# Loss: 0.8366 | Accuracy: 0.7964
# Loss: 0.7701 | Accuracy: 0.7919
# Loss: 0.6673 | Accuracy: 0.7909
# Loss: 0.7088 | Accuracy: 0.8123
#
# Testing 30.0% online...
# Synthetic Training...
# Loss: 152689.5469
# Loss: 153323.9375
# Loss: 155018.3750
# Loss: 152835.9844
# Loss: 155378.7344
# Loss: 155933.0938
# Loss: 152251.7812
# Loss: 151495.0938
# Loss: 151576.7656
# Loss: 150679.6562
# Loss: 148651.5781
# Loss: 142855.1875
# Natural Training...
# Loss: 2.4506 | Accuracy: 0.0958
# Loss: 2.3255 | Accuracy: 0.1065
# Loss: 2.3565 | Accuracy: 0.1099
# Loss: 2.2913 | Accuracy: 0.1327
# Loss: 2.2581 | Accuracy: 0.2309
# Loss: 2.2403 | Accuracy: 0.1671
# Loss: 2.2176 | Accuracy: 0.2262
# Loss: 2.2063 | Accuracy: 0.2192
# Loss: 2.1898 | Accuracy: 0.2741
# Loss: 2.1636 | Accuracy: 0.3203
# Loss: 2.1044 | Accuracy: 0.4625
# Loss: 2.0875 | Accuracy: 0.5209
# Loss: 2.0864 | Accuracy: 0.5308
# Loss: 1.9864 | Accuracy: 0.5529
# Loss: 1.9907 | Accuracy: 0.4902
# Loss: 1.8371 | Accuracy: 0.4683
# Loss: 1.8100 | Accuracy: 0.5285
# Loss: 1.7138 | Accuracy: 0.6056
# Loss: 1.7141 | Accuracy: 0.6699
# Loss: 1.4729 | Accuracy: 0.6861
# Loss: 1.5443 | Accuracy: 0.6604
# Loss: 1.2230 | Accuracy: 0.6858
# Loss: 1.3994 | Accuracy: 0.7007
# Loss: 1.2034 | Accuracy: 0.6897
# Loss: 1.0658 | Accuracy: 0.7304
# Loss: 1.0615 | Accuracy: 0.6977
# Loss: 0.9589 | Accuracy: 0.7113
# Loss: 1.0204 | Accuracy: 0.7681
#
# Testing 40.0% online...
# Synthetic Training...
# Loss: 156697.3750
# Loss: 152312.2969
# Loss: 155503.9062
# Loss: 151158.6719
# Loss: 150813.8750
# Loss: 153432.8750
# Loss: 153156.1719
# Loss: 153459.6875
# Loss: 149951.9219
# Loss: 149913.1094
# Loss: 146664.5469
# Loss: 144933.6562
# Loss: 137200.6250
# Loss: 133467.0312
# Loss: 123993.2188
# Loss: 115631.1641
# Natural Training...
# Loss: 3.2324 | Accuracy: 0.0980
# Loss: 2.4313 | Accuracy: 0.1393
# Loss: 2.4199 | Accuracy: 0.1010
# Loss: 2.3136 | Accuracy: 0.1115
# Loss: 2.3204 | Accuracy: 0.1215
# Loss: 2.2833 | Accuracy: 0.2520
# Loss: 2.1898 | Accuracy: 0.1446
# Loss: 2.2357 | Accuracy: 0.2814
# Loss: 2.1883 | Accuracy: 0.4512
# Loss: 2.1542 | Accuracy: 0.3499
# Loss: 2.0660 | Accuracy: 0.3296
# Loss: 2.1265 | Accuracy: 0.2989
# Loss: 2.0510 | Accuracy: 0.3444
# Loss: 2.0214 | Accuracy: 0.4333
# Loss: 2.0533 | Accuracy: 0.4941
# Loss: 1.9009 | Accuracy: 0.4592
# Loss: 1.8740 | Accuracy: 0.5734
# Loss: 1.8678 | Accuracy: 0.5649
# Loss: 1.8810 | Accuracy: 0.5707
# Loss: 1.7980 | Accuracy: 0.6325
# Loss: 1.6976 | Accuracy: 0.5886
# Loss: 1.7600 | Accuracy: 0.5746
# Loss: 1.6317 | Accuracy: 0.6241
# Loss: 1.5570 | Accuracy: 0.6422
#
# Testing 50.0% online...
# Synthetic Training...
# Loss: 155487.9375
# Loss: 152982.9688
# Loss: 154901.0312
# Loss: 153552.1250
# Loss: 152373.8438
# Loss: 154227.9219
# Loss: 151380.8750
# Loss: 154879.9062
# Loss: 152705.0312
# Loss: 149616.4219
# Loss: 149531.4062
# Loss: 148106.3906
# Loss: 143386.6250
# Loss: 136749.3125
# Loss: 131310.2812
# Loss: 122130.8125
# Loss: 117567.4453
# Loss: 108086.3359
# Loss: 95784.8594
# Loss: 85834.4844
# Natural Training...
# Loss: 4.4181 | Accuracy: 0.0715
# Loss: 3.5018 | Accuracy: 0.1343
# Loss: 3.4260 | Accuracy: 0.1135
# Loss: 2.7083 | Accuracy: 0.1175
# Loss: 3.0159 | Accuracy: 0.1750
# Loss: 2.8419 | Accuracy: 0.1351
# Loss: 2.4749 | Accuracy: 0.1010
# Loss: 2.3598 | Accuracy: 0.1010
# Loss: 2.3091 | Accuracy: 0.1220
# Loss: 2.2866 | Accuracy: 0.1750
# Loss: 2.2262 | Accuracy: 0.1567
# Loss: 2.2542 | Accuracy: 0.1658
# Loss: 2.2261 | Accuracy: 0.1046
# Loss: 2.1601 | Accuracy: 0.2522
# Loss: 2.1748 | Accuracy: 0.3241
# Loss: 2.1633 | Accuracy: 0.2916
# Loss: 2.1437 | Accuracy: 0.3876
# Loss: 2.1126 | Accuracy: 0.3357
# Loss: 2.1026 | Accuracy: 0.3623
# Loss: 2.1213 | Accuracy: 0.4134
#
# Testing 60.0% online...
# Synthetic Training...
# Loss: 152163.2812
# Loss: 153793.2500
# Loss: 153328.0938
# Loss: 152483.8438
# Loss: 153300.7969
# Loss: 155252.4531
# Loss: 153483.3438
# Loss: 151554.7812
# Loss: 152410.1562
# Loss: 151355.7656
# Loss: 149170.7188
# Loss: 145832.4062
# Loss: 144570.5625
# Loss: 139709.3438
# Loss: 132973.5625
# Loss: 125836.9375
# Loss: 117646.4141
# Loss: 108927.0781
# Loss: 97691.3750
# Loss: 89664.2656
# Loss: 78256.9062
# Loss: 66639.1484
# Loss: 59107.0586
# Loss: 50014.6523
# Natural Training...
# Loss: 14.1586 | Accuracy: 0.0958
# Loss: 9.8185 | Accuracy: 0.0958
# Loss: 9.3600 | Accuracy: 0.0962
# Loss: 8.3945 | Accuracy: 0.0982
# Loss: 6.5772 | Accuracy: 0.0972
# Loss: 5.8194 | Accuracy: 0.0980
# Loss: 5.6422 | Accuracy: 0.0980
# Loss: 5.2293 | Accuracy: 0.1032
# Loss: 3.9689 | Accuracy: 0.1367
# Loss: 3.3528 | Accuracy: 0.0955
# Loss: 3.4425 | Accuracy: 0.0957
# Loss: 3.3756 | Accuracy: 0.1478
# Loss: 2.4909 | Accuracy: 0.2017
# Loss: 2.6098 | Accuracy: 0.2124
# Loss: 2.5479 | Accuracy: 0.1091
# Loss: 2.2984 | Accuracy: 0.1150
#
# Testing 70.0% online...
# Synthetic Training...
# Loss: 153917.7969
# Loss: 151602.9688
# Loss: 154096.8750
# Loss: 151939.2812
# Loss: 154394.0312
# Loss: 152788.7812
# Loss: 152439.0156
# Loss: 153556.0000
# Loss: 152815.1719
# Loss: 150243.6250
# Loss: 151233.4688
# Loss: 146479.9531
# Loss: 143250.1094
# Loss: 139892.3281
# Loss: 132419.8125
# Loss: 125777.3438
# Loss: 119394.2656
# Loss: 106957.8438
# Loss: 96548.8906
# Loss: 87530.0938
# Loss: 77097.8594
# Loss: 66439.7891
# Loss: 57072.7617
# Loss: 48494.1523
# Loss: 41614.7031
# Loss: 35234.7734
# Loss: 29780.0332
# Loss: 25499.4277
# Natural Training...
# Loss: 25.7507 | Accuracy: 0.0892
# Loss: 21.8847 | Accuracy: 0.1032
# Loss: 19.4325 | Accuracy: 0.1040
# Loss: 15.1752 | Accuracy: 0.0978
# Loss: 10.3426 | Accuracy: 0.0980
# Loss: 9.6026 | Accuracy: 0.0885
# Loss: 8.4242 | Accuracy: 0.1028
# Loss: 6.1249 | Accuracy: 0.1004
# Loss: 5.6365 | Accuracy: 0.0977
# Loss: 5.2775 | Accuracy: 0.0958
# Loss: 4.6072 | Accuracy: 0.1298
# Loss: 4.4548 | Accuracy: 0.1010
#
# Testing 80.0% online...
# Synthetic Training...
# Loss: 154389.2344
# Loss: 153660.2344
# Loss: 153510.4062
# Loss: 153798.0312
# Loss: 151877.2500
# Loss: 154784.4844
# Loss: 151401.8125
# Loss: 152819.6250
# Loss: 153103.3281
# Loss: 151361.3906
# Loss: 152128.4844
# Loss: 146296.5469
# Loss: 145689.0312
# Loss: 140158.4844
# Loss: 134724.2812
# Loss: 126356.7734
# Loss: 121300.0703
# Loss: 112012.5000
# Loss: 104306.4609
# Loss: 92710.0391
# Loss: 81409.5625
# Loss: 71773.3281
# Loss: 59820.7891
# Loss: 51591.8711
# Loss: 47354.3984
# Loss: 38509.9805
# Loss: 33768.6641
# Loss: 28825.4570
# Loss: 24454.6074
# Loss: 22123.4531
# Loss: 19613.4922
# Loss: 18214.6875
# Natural Training...
# Loss: 16.2307 | Accuracy: 0.0980
# Loss: 10.2780 | Accuracy: 0.0980
# Loss: 10.3961 | Accuracy: 0.0958
# Loss: 9.7510 | Accuracy: 0.1005
# Loss: 7.8110 | Accuracy: 0.1003
# Loss: 5.3593 | Accuracy: 0.0976
# Loss: 4.3049 | Accuracy: 0.1028
# Loss: 4.5267 | Accuracy: 0.1029
#
# Testing 90.0% online...
# Synthetic Training...
# Loss: 155849.4688
# Loss: 155582.9062
# Loss: 155071.7344
# Loss: 153478.8438
# Loss: 152824.1719
# Loss: 151575.0156
# Loss: 152918.1562
# Loss: 150994.0312
# Loss: 152282.3438
# Loss: 153512.1875
# Loss: 151164.3906
# Loss: 149249.5000
# Loss: 146325.5000
# Loss: 145127.5312
# Loss: 138544.1875
# Loss: 136398.7969
# Loss: 127019.8906
# Loss: 121300.9062
# Loss: 112963.6719
# Loss: 104093.2969
# Loss: 93725.3672
# Loss: 86686.4766
# Loss: 77864.5703
# Loss: 67193.5781
# Loss: 61181.0820
# Loss: 53531.5234
# Loss: 47822.9648
# Loss: 41787.1641
# Loss: 37796.6289
# Loss: 34839.1641
# Loss: 31812.5742
# Loss: 29401.1504
# Loss: 27954.4238
# Loss: 26970.8594
# Loss: 26410.6465
# Loss: 26286.0820
# Natural Training...
# Loss: 23.1626 | Accuracy: 0.0982
# Loss: 18.1143 | Accuracy: 0.0982
# Loss: 15.3414 | Accuracy: 0.0982
# Loss: 12.1769 | Accuracy: 0.0982

# %% [markdown]
# ### Analysis
#
# Plot times

# %%
# Plotting
x  = list(times.keys())
tm = list(times.values())

plt.plot(x, tm, marker='o')
plt.xlabel('Proportion of Training Which Is Online')
plt.ylabel('Computation Time')
plt.title('')
plt.grid(True)
plt.show()

# %% [markdown]
# Plot Final Accuracies

# %%
fa = [acc[-1] if acc else 0 for acc in accuracies.values()]
plt.plot(x, fa, marker='o')
plt.xlabel('Proportion of Training Which Is Online')
plt.ylabel('Final Accuracies')
plt.title('')
plt.grid(True)
plt.show()

# %% [markdown]
# Plot Final Losses

# %%
fl = [l[-1] if l else 0 for l in losses.values()]
plt.plot(x, fl, marker='o')
plt.xlabel('Proportion of Training Which Is Online')
plt.ylabel('Final Losses')
plt.title('')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

x = list(times.keys())
tm = list(times.values())

plt.figure(figsize=(6, 4))  # Slightly bigger figure
plt.plot(x, tm, marker='o', markersize=8, linestyle='-', linewidth=2)

plt.xlabel('Proportion of Training Which Is Online', fontsize=14)
plt.ylabel('Computation Time (s)', fontsize=14)
plt.title('Training Time vs. Online Warmup', fontsize=16)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-711e11862c81> in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 x = list(times.keys())
#       4 tm = list(times.values())
#       5
#
# NameError: name 'times' is not defined
